# %%
# %load_ext autoreload
# %autoreload 2
from test2 import main

# %%
main()
# Out:
# Given n vectors in d-dimensional Euclidean space where
# n 40
# d 10
# Suppose we have an O(d)-equivariant function f(x_1,...,x_n)
# which outputs a d x d matrix A
# Assume that A = sum_{i j} alpha_{i j} where only s alpha_{i j} nonzero
# s 15
# Suppose we are given the value of the function f for ns random vectors
# ns 2
# this results in a system of size (200, 1600)
# We try the solve this using HTP
# idx1 [ 235  242  275  368  558  584  591  793  818  918 1155 1528 1535 1544
#  1558]
# idx [ 235  242  275  368  558  584  591  793  818  918 1155 1528 1535 1544
#  1558]
# err [5.68287578e-01 2.17816135e-01 1.04708254e-01 2.68310669e-02
#  1.29479522e-15 1.29479522e-15 1.29479522e-15 1.29479522e-15
#  1.29479522e-15 1.29479522e-15]
